# %%
import os
import numpy as np
import cv2
import matplotlib
import matplotlib.pyplot as plt
import tensorflow as tf

# (x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# x_train = x_train.astype("float32") / 255.0
# x_test  = x_test.astype("float32") / 255.0


# model = tf.keras.Sequential([
#    tf.keras.layers.Flatten(input_shape=(28, 28)),
#    tf.keras.layers.Dense(128, activation='relu'),
#    tf.keras.layers.Dense(128, activation='relu'),
#     tf.keras.layers.Dense(10, activation='softmax')
# ])
# model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# model.fit(x_train, y_train, epochs=6, validation_data=(x_test, y_test))


# model.save('handwritten.keras')   # <- this is the new default format to use

m2 = tf.keras.models.load_model('handwritten.keras')


image_number = 1
while os.path.isfile(f"digits/digit{image_number}.png"):
  try:

    img = cv2.imread(f"digits/digit{image_number}.png")[:,:,0]
    img = np.invert(np.array([img]))
    prediction = m2.predict(img)
    print(f"This difit is probably a {np.argmax(prediction)}")
    plt.imshow(img[0], cmap=plt.cm.binary)
    plt.show()
  except:
    print("Error!")
  finally:
    image_number += 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-796479458.py in <cell line: 0>()
#      23 # model.save('handwritten.keras')   # <- this is the new default format to use
#      24
# ---> 25 m2 = tf.keras.models.load_model('handwritten.keras')
#      26
#      27
#
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     198         )
#     199     elif str(filepath).endswith(".keras"):
# --> 200         raise ValueError(
#     201             f"File not found: filepath={filepath}. "
#     202             "Please ensure the file is an accessible `.keras` "
#
# ValueError: File not found: filepath=handwritten.keras. Please ensure the file is an accessible `.keras` zip file.

# %%
# !zip -r project.zip digits sample_data handwritten.keras
# Out:
# 	zip warning: name not matched: digits
# 	zip warning: name not matched: handwritten.keras
#   adding: sample_data/ (stored 0%)
#   adding: sample_data/README.md (deflated 39%)
#   adding: sample_data/anscombe.json (deflated 83%)
#   adding: sample_data/mnist_train_small.csv (deflated 88%)
#   adding: sample_data/california_housing_test.csv (deflated 76%)
#   adding: sample_data/mnist_test.csv (deflated 88%)
#   adding: sample_data/california_housing_train.csv (deflated 79%)

# %%
# !ls
# Out:
# digits	handwritten.keras  project.zip	sample_data
